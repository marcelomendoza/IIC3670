# %% [markdown]
# # IIC-3670 NLP UC

# %% [markdown]
# - Versiones de librerías, python > 3.8.10
#
# - numpy 1.20.3
# - nltk 3.7
# - scikit-learn 1.0+
# - gensim 4.3+

# %%
corpus = [
    "This automobile is fuel efficient and reliable for daily commuting",
    "The vehicle handles well on the highway and has a smooth engine",
    "Sedan with excellent gas mileage, perfect for city driving",
    "Affordable smartphone with a great camera and long battery life",
    "This mobile device has an amazing display and fast processor",
    "The handset offers excellent performance at a reasonable price",
    "Delicious pasta recipe with fresh tomatoes and basil",
    "Homemade meal using seasonal vegetables and herbs",
    "Traditional dish prepared with local ingredients from the market",
]

queries = [
    "cheap car",
    "phone",
    "food",
]

# %% [markdown]
# ## Actividad en clase
#
# Sobre el `corpus` y las `queries` de arriba, construya **dos motores de búsqueda** y compárelos:
#
# - **Motor TF-IDF**: vectorice el corpus con `TfidfVectorizer`, transforme cada consulta, calcule la similitud coseno contra cada documento y muestre el **top-1** con su score.
# - **Motor Word2Vec**: use el modelo pre-entrenado `word2vec-google-news-300` (mismo del Jupyter 4). Represente cada documento y cada consulta como el **promedio de los vectores** de sus palabras (ignorando las que no estén en el vocabulario). Calcule similitud coseno y muestre el **top-1** con su score.
# - Corra ambos motores para las 3 consultas y **compare los resultados**: ¿cuál acierta y cuál falla en cada caso? ¿Por qué?
# - Cuanto termine, me avisa para entregarle una **L (logrado)**.
# - Recuerde que las L otorgan un bono en la nota final de la asignatura.
#
# ***Tiene hasta el final de la clase.***
