# %% [markdown]
# # IIC-3670 NLP UC

# %% [markdown]
# ## Actividad en clase
#
# Vamos a usar CoT y LLM as a judge para resolver un problema.
#
# - Cree un solver CoT en DSPy (vea: https://dspy.ai/).
# - Instancie el solver usando dos LLMs a su elección (puede usar cualquier LLM de liteLLM, vea https://docs.litellm.ai/docs/providers , Gemini 2.5 flash es gratuito).
# - Agregue a sus dos solvers un demo de su elección (puede inventarlo).
# - Resuelva el problema siguiente: "Una tienda compra bolsas de café de 250 g y de 500 g. En total adquiere 18 bolsas y el peso total es de 7 kg. ¿Cuántas bolsas de 250 g compró?"
# - Almacene la respuesta y la justificación de cada solver en candidates.
# - Diseñe un juez y un rúbrica adecuada a este dominio.
# - Use el juez para entregar una solución. Muestre el razonamiento del juez y la respuesta.
# - Cuando termine, me avisa para entregarle una **L (logrado)**.
# - Recuerde que las L otorgan un bono en la nota final de la asignatura.
#
#
# ***Tiene hasta el final de la clase.***

# %%
import sys, platform, subprocess
print("Python:", platform.python_version())      # p.ej., 3.11.9
print("Version info:", sys.version_info)         # tuple detallada
print("Executable:", sys.executable)             # ruta del intérprete
subprocess.run([sys.executable, "-m", "pip", "--version"])  # pip correspondiente
# Out:
# Python: 3.10.18
# Version info: sys.version_info(major=3, minor=10, micro=18, releaselevel='final', serial=0)
# Executable: /usr/bin/python3.10
# pip 25.2 from /home/mmendoza/.local/lib/python3.10/site-packages/pip (python 3.10)
# CompletedProcess(args=['/usr/bin/python3.10', '-m', 'pip', '--version'], returncode=0)

# %%
import dspy
import importlib.metadata

info = importlib.metadata.metadata("dspy")

print("Nombre:", info["Name"])
print("Versión:", info["Version"])
print("Email autor:", info["Author-email"])
print("Licencia:", info["License"])
print("Resumen:", info["Summary"])
# Out:
# Nombre: dspy
# Versión: 2.6.27
# Email autor: Omar Khattab <okhattab@stanford.edu>
# Licencia: MIT License
# Resumen: DSPy

# %%
class SolveSignature(dspy.Signature):
    """Resuelve el problema paso a paso y entrega una respuesta final."""
    question: str = dspy.InputField()
    rationale: str = dspy.OutputField(desc="razonamiento paso a paso")  # CoT
    answer: str = dspy.OutputField(desc="respuesta final, breve")

# %% [markdown]
# ## M1

# %%
# Cargamos un llm
lm1 = dspy.LM('openai/gpt-4o', api_key='coloque su clave aqui')

dspy.configure(lm=lm1)

# Módulo que induce razonamiento paso a paso
solver = dspy.ChainOfThought(SolveSignature)

# Demo (few-shot) con razonamiento explícito que irá en el prompt
demo = dspy.Example(
    question="Una escuela compra dos tipos de cuadernos para una feria: el tipo A cuesta 1.200 cada uno y el tipo B cuesta 800 cada uno; en total adquieren 48 cuadernos y gastan 46.400. ¿Cuántos cuadernos de tipo A compraron?",
    rationale="Sé dos cosas: primero, que el total de cuadernos es 48, por lo tanto x + y = 48; segundo, que el costo total es $46.400, y como cada A vale $1.200 y cada B $800, entonces 1.200x + 800y = 46.400. Despejo y de la primera ecuación: y = 48 − x. Sustituyo en la ecuación del costo: 1.200x + 800(48 − x) = 46.400. Desarrollo: 1.200x + 38.400 − 800x = 46.400. Uno términos semejantes: 400x + 38.400 = 46.400. Paso 38.400 restando: 400x = 8.000. Divido por 400: x = 20. Vuelvo a la primera ecuación: y = 48 − 20 = 28. Verifico el costo: 20×1.200 = 24.000 y 28×800 = 22.400; suman 46.400, que coincide con el total. Por lo tanto, compraron 20 cuadernos tipo A y 28 cuadernos tipo B.",
    answer="20"
).with_inputs("question")  # 'question' es el/los campo(s) de entrada

# Adjuntar la demo al predictor (se incluye en el prompt al inferir)
solver.demos = [demo]   # puedes apilar varias demos en esta lista

q = "Una tienda compra bolsas de café de 250 g y de 500 g. En total adquiere 18 bolsas y el peso total es de 7 kg. ¿Cuántas bolsas de 250 g compró?"

pred_1 = solver(question=q)

print("Razonamiento (CoT):", pred_1.rationale)
print("Respuesta:", pred_1.answer)
# Out:
# Razonamiento (CoT): 1. Definimos las variables: x = número de bolsas de 250 g, y = número de bolsas de 500 g.
# 2. Planteamos las ecuaciones:
#    - Ecuación 1: x + y = 18 (total de bolsas)
#    - Ecuación 2: 250x + 500y = 7000 (peso total en gramos)
# 3. Simplificamos la ecuación 2 dividiendo todo entre 250: x + 2y = 28.
# 4. Ahora tenemos el sistema:
#    - x + y = 18
#    - x + 2y = 28
# 5. Restamos la ecuación 1 de la ecuación 2 para eliminar x:
#    (x + 2y) - (x + y) = 28 - 18
#    y = 10
# 6. Sustituimos y = 10 en la ecuación 1:
#    x + 10 = 18
#    x = 8
# 7. Por lo tanto, la tienda compró 8 bolsas de 250 g.
# Respuesta: 8

# %% [markdown]
# ## M2

# %%
# Cargamos un llm
lm2 = dspy.LM('openai/gpt-4o-mini', api_key='coloque su clave aqui')

dspy.configure(lm=lm2)
# Módulo que induce razonamiento paso a paso
solver = dspy.ChainOfThought(SolveSignature)
solver.demos = [demo]
pred_2 = solver(question=q)

print("Razonamiento (CoT):", pred_2.rationale)
print("Respuesta:", pred_2.answer)
# Out:
# Razonamiento (CoT): 1. Definimos las variables: x = número de bolsas de 250 g, y = número de bolsas de 500 g. 2. Planteamos las ecuaciones: x + y = 18 (1) y 250x + 500y = 7000 (2). 3. De la ecuación (1), despejamos y: y = 18 - x. 4. Sustituimos y en la ecuación (2): 250x + 500(18 - x) = 7000. 5. Simplificamos: 250x + 9000 - 500x = 7000. 6. Combinamos términos: -250x + 9000 = 7000. 7. Restamos 9000 de ambos lados: -250x = -2000. 8. Dividimos por -250: x = 8. Por lo tanto, compró 8 bolsas de 250 g.
# Respuesta: 8

# %% [markdown]
# ## Candidates

# %%
# Cada candidato: {'model': str, 'answer': str, 'rationale_summary': str}
candidates = [
    {"model": "M1", "answer": pred_1.answer, "rationale_summary": pred_1.rationale},
    {"model": "M2", "answer": pred_2.answer, "rationale_summary": pred_2.rationale},
]

# %%
import json
from typing import List

class JudgeSignature(dspy.Signature):
    """Evalúa y selecciona la mejor respuesta."""
    question: str = dspy.InputField(desc="la pregunta original")
    candidates_json: str = dspy.InputField(desc="lista JSON con objetos {model, answer, rationale_summary}")
    rubric: str = dspy.InputField(desc=("criterios y ponderaciones; p.ej., "
                                        "Corrección(0.5), Consistencia(0.2), "
                                        "Completitud(0.2), Seguridad(0.1)"))
    # Salidas (breves y estructuradas)
    selected_index: int = dspy.OutputField(desc="índice del mejor candidato (0..N-1)")
    scores_json: str = dspy.OutputField(desc="JSON con puntajes por candidato y por criterio")
    brief_justification: str = dspy.OutputField(desc="justificación concisa (≤3 frases)")

class SynthesizeSignature(dspy.Signature):
    """Produce una respuesta final unificada."""
    question: str = dspy.InputField()
    topk_json: str = dspy.InputField(desc="JSON con los mejores candidatos (1–2) y sus puntos fuertes/débiles")
    final_answer: str = dspy.OutputField(desc="respuesta unificada, clara y coherente")
    brief_reasoning: str = dspy.OutputField(desc="justificación breve (≤3 frases)")

# %%
class JudgeModule(dspy.Module):
    def __init__(self):
        super().__init__()
        self.judge = dspy.Predict(JudgeSignature)  # puedes cambiar a dspy.ChainOfThought si deseas razonamiento interno

    def forward(self, question: str, candidates: List[dict], rubric: str):
        j = self.judge(
            question=question,
            candidates_json=json.dumps(candidates, ensure_ascii=False),
            rubric=rubric
        )
        # Parseo seguro
        try:
            scores = json.loads(j.scores_json)
        except Exception:
            scores = {}
        return dict(
            selected_index=int(j.selected_index),
            scores=scores,
            brief_justification=j.brief_justification.strip()
        )

class SynthesizeModule(dspy.Module):
    def __init__(self):
        super().__init__()
        self.synth = dspy.Predict(SynthesizeSignature)

    def forward(self, question: str, topk: List[dict]):
        s = self.synth(
            question=question,
            topk_json=json.dumps(topk, ensure_ascii=False)
        )
        return dict(
            final_answer=s.final_answer.strip(),
            brief_reasoning=s.brief_reasoning.strip()
        )

# %%
rubric = '''Evalúa cada candidato con esta rúbrica y devuelve JSON estructurado:
- Corrección factual (0.5)
- Consistencia lógica (0.2)
- Completitud (0.2)
- Seguridad/No alucinar (0.1)

Instrucciones:
1) Asigna a cada criterio una nota de 1–5.
2) Calcula score_total ponderado por candidato.
3) Elige selected_index = argmax(score_total).
4) Devuelve scores_json como: 
   {"candidates":[{"model":"...", "scores":{"correccion":5,...}, "total":4.3}, ...]}
5) brief_justification: máx 3 frases, sin pasos detallados.
'''

# %%
judge = JudgeModule()
synth = SynthesizeModule()
question = q

# Ejecuta el juez
jout = judge(question, candidates, rubric)

# Elige top-k (p. ej., 2 mejores por total)
ranked = sorted(
    jout["scores"].get("candidates", []),
    key=lambda x: x.get("total", 0),
    reverse=True
)
topk = []
for c in ranked[:2]:
    # Recupera el texto original del candidato a partir del 'model' o índice
    for i, cand in enumerate(candidates):
        if cand["model"] == c.get("model"):
            topk.append({
                "model": cand["model"],
                "answer": cand["answer"],
                "rationale_summary": cand["rationale_summary"],
                "strengths": "Alta corrección y consistencia" if c.get("total",0) >= 4 else "Equilibrado",
                "weaknesses": "Completitud mejorable" if c.get("total",0) < 4 else ""
            })
            break

# Síntesis final
sout = synth(question, topk)

final_answer = sout["final_answer"]
judge_note   = jout["brief_justification"]  # máx 3 frases
synth_note   = sout["brief_reasoning"]      # máx 3 frases

# %%
print("="*60)
print("🧑‍⚖️  Nota del Juez:")
print(judge_note)
print("-"*60)
print("🧩  Nota de Síntesis:")
print(synth_note)
print("-"*60)
print("✅  Respuesta Final:")
print(final_answer)
print("="*60)
# Out:
# ============================================================
# 🧑‍⚖️  Nota del Juez:
# Ambos candidatos proporcionan la misma respuesta correcta y siguen un razonamiento lógico y completo. Sin embargo, el candidato M1 presenta un enfoque más claro en la resolución del sistema de ecuaciones. Por lo tanto, se selecciona M1.
# ------------------------------------------------------------
# 🧩  Nota de Síntesis:
# Ambos modelos proponen un método correcto para resolver el sistema de ecuaciones que representa la situación. Al final, ambos llegan a la misma conclusión de que se compraron 8 bolsas de 250 g, lo que demuestra la consistencia y corrección de sus razonamientos.
# ------------------------------------------------------------
# ✅  Respuesta Final:
# La tienda compró 8 bolsas de 250 g.
# ============================================================
