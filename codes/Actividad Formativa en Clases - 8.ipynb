# %% [markdown]
# # IIC-3670 NLP UC

# %% [markdown]
# - Versiones de librerías, python 3.8.10
#
# - numpy 1.23.5
# - torch 1.10.0

# %% [markdown]
# ____________________________________________________________________________________________________________
#
# ## Actividad en clase
#
# Evaluaremos varios modelos **GPT text**. Para esto haga lo siguiente:
#
# - Complete el jupyter 14, reemplazando en la función eval_split las secuencias de enteros por secuencias de tokens. Use la función **get_vocab_lookup(vocab)** del jupyter 11 para abordar esto.
# - Corra gpt con SPLIT = 0.7. Mida el error rate y success rate del modelo sobre los 4 útimos tokens de cada secuencia de testing. Reporte los rates globales.
# - Vuelva a correr eval_split subiendo la temperatura a 0.5. Reporte los rates globales. Comente los resultados.
# - Comente los resultados de la comparación.
# - Cuanto termine, me avisa para entregarle una **L (logrado)**.
# - Recuerde que las L otorgan un bono en la nota final de la asignatura.
#
#
# ***Tiene hasta el final de la clase.***
#
# _________________________________________________________________________________________________________________

# %% [markdown]
# # Solución

# %%
import math
import torch
import torch.nn as nn
from torch.nn import functional as F
import bpe
from utils import CfgNode as CN

# %%
class NewGELU(nn.Module):
    def forward(self, x):
        return 0.5 * x * (1.0 + torch.tanh(math.sqrt(2.0 / math.pi) * (x + 0.044715 * torch.pow(x, 3.0))))

class CausalSelfAttention(nn.Module):

    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        # key, query, value projections for all heads, but in a batch
        self.c_attn = nn.Linear(config.n_embd, 3 * config.n_embd)
        # output projection
        self.c_proj = nn.Linear(config.n_embd, config.n_embd)
        # regularization
        self.attn_dropout = nn.Dropout(config.attn_pdrop)
        self.resid_dropout = nn.Dropout(config.resid_pdrop)
        # causal mask to ensure that attention is only applied to the left in the input sequence
        self.register_buffer("bias", torch.tril(torch.ones(config.block_size, config.block_size))
                                     .view(1, 1, config.block_size, config.block_size))
        self.n_head = config.n_head
        self.n_embd = config.n_embd

    def forward(self, x):
        B, T, C = x.size() # batch size, sequence length, embedding dimensionality (n_embd)

        # calculate query, key, values for all heads in batch and move head forward to be the batch dim
        q, k ,v  = self.c_attn(x).split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)

        # causal self-attention; Self-attend: (B, nh, T, hs) x (B, nh, hs, T) -> (B, nh, T, T)
        att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
        att = att.masked_fill(self.bias[:,:,:T,:T] == 0, float('-inf'))
        att = F.softmax(att, dim=-1)
        att = self.attn_dropout(att)
        y = att @ v # (B, nh, T, T) x (B, nh, T, hs) -> (B, nh, T, hs)
        y = y.transpose(1, 2).contiguous().view(B, T, C) # re-assemble all head outputs side by side

        # output projection
        y = self.resid_dropout(self.c_proj(y))
        return y

# %%
class Block(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.ln_1 = nn.LayerNorm(config.n_embd)
        self.attn = CausalSelfAttention(config)
        self.ln_2 = nn.LayerNorm(config.n_embd)
        self.mlp = nn.ModuleDict(dict(
            c_fc    = nn.Linear(config.n_embd, 4 * config.n_embd),
            c_proj  = nn.Linear(4 * config.n_embd, config.n_embd),
            act     = NewGELU(),
            dropout = nn.Dropout(config.resid_pdrop),
        ))
        m = self.mlp
        self.mlpf = lambda x: m.dropout(m.c_proj(m.act(m.c_fc(x)))) # MLP forward

    def forward(self, x):
        x = x + self.attn(self.ln_1(x))
        x = x + self.mlpf(self.ln_2(x))
        return x

# %%
class GPT(nn.Module):
    """ GPT Language Model """

    @staticmethod
    def get_default_config():
        C = CN()
        # either model_type or (n_layer, n_head, n_embd) must be given in the config
        C.model_type = 'gpt'
        C.n_layer = None
        C.n_head = None
        C.n_embd =  None
        # these options must be filled in externally
        C.vocab_size = None
        C.block_size = None
        # dropout hyperparameters
        C.embd_pdrop = 0.1
        C.resid_pdrop = 0.1
        C.attn_pdrop = 0.1
        return C
    
    
    def __init__(self, config):
        super().__init__()
        assert config.vocab_size is not None
        assert config.block_size is not None
        self.block_size = config.block_size

        type_given = config.model_type is not None
        params_given = all([config.n_layer is not None, config.n_head is not None, config.n_embd is not None])
        assert type_given ^ params_given # exactly one of these (XOR)
        if type_given:
            # translate from model_type to detailed configuration
            config.merge_from_dict({
                # names follow the huggingface naming conventions
                # GPT-1
                'openai-gpt':   dict(n_layer=12, n_head=12, n_embd=768),  # 117M params
                # GPT-2 configs
                'gpt2':         dict(n_layer=12, n_head=12, n_embd=768),  # 124M params
                'gpt2-medium':  dict(n_layer=24, n_head=16, n_embd=1024), # 350M params
                'gpt2-large':   dict(n_layer=36, n_head=20, n_embd=1280), # 774M params
                'gpt2-xl':      dict(n_layer=48, n_head=25, n_embd=1600), # 1558M params
                # Gophers
                'gopher-44m':   dict(n_layer=8, n_head=16, n_embd=512),
                # (there are a number more...)
                # I made these tiny models up
                'gpt-mini':     dict(n_layer=6, n_head=6, n_embd=192),
                'gpt-micro':    dict(n_layer=4, n_head=4, n_embd=128),
                'gpt-nano':     dict(n_layer=3, n_head=3, n_embd=48),
            }[config.model_type])

        self.transformer = nn.ModuleDict(dict(
            wte = nn.Embedding(config.vocab_size, config.n_embd),
            wpe = nn.Embedding(config.block_size, config.n_embd),
            drop = nn.Dropout(config.embd_pdrop),
            h = nn.ModuleList([Block(config) for _ in range(config.n_layer)]),
            ln_f = nn.LayerNorm(config.n_embd),
        ))
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)

        # init all weights, and apply a special scaled init to the residual projections, per GPT-2 paper
        self.apply(self._init_weights)
        for pn, p in self.named_parameters():
            if pn.endswith('c_proj.weight'):
                torch.nn.init.normal_(p, mean=0.0, std=0.02/math.sqrt(2 * config.n_layer))

        # report number of parameters (note we don't count the decoder parameters in lm_head)
        n_params = sum(p.numel() for p in self.transformer.parameters())
        print("number of parameters: %.2fM" % (n_params/1e6,))
    
    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
        elif isinstance(module, nn.LayerNorm):
            torch.nn.init.zeros_(module.bias)
            torch.nn.init.ones_(module.weight)
    
    @classmethod
    def from_pretrained(cls, model_type):
        """
        Initialize a pretrained GPT model by copying over the weights
        from a huggingface/transformers checkpoint.
        """
        assert model_type in {'gpt2', 'gpt2-medium', 'gpt2-large', 'gpt2-xl'}
        from transformers import GPT2LMHeadModel

        # create a from-scratch initialized minGPT model
        config = cls.get_default_config()
        config.model_type = model_type
        config.vocab_size = 50257 # openai's model vocabulary
        config.block_size = 1024  # openai's model block_size
        model = GPT(config)
        sd = model.state_dict()

        # init a huggingface/transformers model
        model_hf = GPT2LMHeadModel.from_pretrained(model_type)
        sd_hf = model_hf.state_dict()

        # copy while ensuring all of the parameters are aligned and match in names and shapes
        keys = [k for k in sd_hf if not k.endswith('attn.masked_bias')] # ignore these
        transposed = ['attn.c_attn.weight', 'attn.c_proj.weight', 'mlp.c_fc.weight', 'mlp.c_proj.weight']
        # basically the openai checkpoints use a "Conv1D" module, but we only want to use a vanilla nn.Linear.
        # this means that we have to transpose these weights when we import them
        assert len(keys) == len(sd)
        for k in keys:
            if any(k.endswith(w) for w in transposed):
                # special treatment for the Conv1D weights we need to transpose
                assert sd_hf[k].shape[::-1] == sd[k].shape
                with torch.no_grad():
                    sd[k].copy_(sd_hf[k].t())
            else:
                # vanilla copy over the other parameters
                assert sd_hf[k].shape == sd[k].shape
                with torch.no_grad():
                    sd[k].copy_(sd_hf[k])

        return model
    
    def configure_optimizers(self, train_config):
        """
        This long function is unfortunately doing something very simple and is being very defensive:
        We are separating out all parameters of the model into two buckets: those that will experience
        weight decay for regularization and those that won't (biases, and layernorm/embedding weights).
        We are then returning the PyTorch optimizer object.
        """

        # separate out all parameters to those that will and won't experience regularizing weight decay
        decay = set()
        no_decay = set()
        whitelist_weight_modules = (torch.nn.Linear, )
        blacklist_weight_modules = (torch.nn.LayerNorm, torch.nn.Embedding)
        for mn, m in self.named_modules():
            for pn, p in m.named_parameters():
                fpn = '%s.%s' % (mn, pn) if mn else pn # full param name
                # random note: because named_modules and named_parameters are recursive
                # we will see the same tensors p many many times. but doing it this way
                # allows us to know which parent module any tensor p belongs to...
                if pn.endswith('bias'):
                    # all biases will not be decayed
                    no_decay.add(fpn)
                elif pn.endswith('weight') and isinstance(m, whitelist_weight_modules):
                    # weights of whitelist modules will be weight decayed
                    decay.add(fpn)
                elif pn.endswith('weight') and isinstance(m, blacklist_weight_modules):
                    # weights of blacklist modules will NOT be weight decayed
                    no_decay.add(fpn)

        # validate that we considered every parameter
        param_dict = {pn: p for pn, p in self.named_parameters()}
        inter_params = decay & no_decay
        union_params = decay | no_decay
        assert len(inter_params) == 0, "parameters %s made it into both decay/no_decay sets!" % (str(inter_params), )
        assert len(param_dict.keys() - union_params) == 0, "parameters %s were not separated into either decay/no_decay set!" \
                                                    % (str(param_dict.keys() - union_params), )

        # create the pytorch optimizer object
        optim_groups = [
            {"params": [param_dict[pn] for pn in sorted(list(decay))], "weight_decay": train_config.weight_decay},
            {"params": [param_dict[pn] for pn in sorted(list(no_decay))], "weight_decay": 0.0},
        ]
        optimizer = torch.optim.AdamW(optim_groups, lr=train_config.learning_rate, betas=train_config.betas)
        return optimizer
    
    
    def forward(self, idx, targets=None):
        device = idx.device
        b, t = idx.size()
        assert t <= self.block_size, f"Cannot forward sequence of length {t}, block size is only {self.block_size}"
        pos = torch.arange(0, t, dtype=torch.long, device=device).unsqueeze(0) # shape (1, t)

        # forward the GPT model itself
        tok_emb = self.transformer.wte(idx) # token embeddings of shape (b, t, n_embd)
        pos_emb = self.transformer.wpe(pos) # position embeddings of shape (1, t, n_embd)
        x = self.transformer.drop(tok_emb + pos_emb)
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)
        logits = self.lm_head(x)

        # if we are given some desired targets also calculate the loss
        loss = None
        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1), ignore_index=-1)

        return logits, loss
    
    
    @torch.no_grad()
    def generate(self, idx, max_new_tokens, temperature=1.0, do_sample=False, top_k=None):
        """
        Take a conditioning sequence of indices idx (LongTensor of shape (b,t)) and complete
        the sequence max_new_tokens times, feeding the predictions back into the model each time.
        Most likely you'll want to make sure to be in model.eval() mode of operation for this.
        """
        for _ in range(max_new_tokens):
            # if the sequence context is growing too long we must crop it at block_size
            idx_cond = idx if idx.size(1) <= self.block_size else idx[:, -self.block_size:]
            # forward the model to get the logits for the index in the sequence
            logits, _ = self(idx_cond)
            # pluck the logits at the final step and scale by desired temperature
            logits = logits[:, -1, :] / temperature
            # optionally crop the logits to only the top k options
            if top_k is not None:
                v, _ = torch.topk(logits, top_k)
                logits[logits < v[:, [-1]]] = -float('Inf')
            # apply softmax to convert logits to (normalized) probabilities
            probs = F.softmax(logits, dim=-1)
            # either sample from the distribution or take the most likely element
            if do_sample:
                idx_next = torch.multinomial(probs, num_samples=1)
            else:
                _, idx_next = torch.topk(probs, k=1, dim=-1)
            # append sampled index to the running sequence and continue
            idx = torch.cat((idx, idx_next), dim=1)

        return idx

# %%
import time
from collections import defaultdict
from torch.utils.data.dataloader import DataLoader

class Trainer:

    @staticmethod
    def get_default_config():
        C = CN()
        # device to train on
        #C.device = 'auto'
        C.device = 'cpu'
        # dataloder parameters
        C.num_workers = 4
        # optimizer parameters
        C.max_iters = None
        C.batch_size = 64
        C.learning_rate = 3e-4
        C.betas = (0.9, 0.95)
        C.weight_decay = 0.1
        C.grad_norm_clip = 1.0
        return C

    def __init__(self, config, model, train_dataset):
        self.config = config
        self.model = model
        self.optimizer = None
        self.train_dataset = train_dataset
        self.callbacks = defaultdict(list)

        # determine the device we'll train on
        if config.device == 'auto':
            self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        else:
            self.device = config.device
        self.model = self.model.to(self.device)
        print("running on device", self.device)

        # variables that will be assigned to trainer class later for logging and etc
        self.iter_num = 0
        self.iter_time = 0.0
        self.iter_dt = 0.0

    def add_callback(self, onevent: str, callback):
        self.callbacks[onevent].append(callback)

    def set_callback(self, onevent: str, callback):
        self.callbacks[onevent] = [callback]

    def trigger_callbacks(self, onevent: str):
        for callback in self.callbacks.get(onevent, []):
            callback(self)

    def run(self):
        model, config = self.model, self.config

        # setup the optimizer
        self.optimizer = model.configure_optimizers(config)

        # setup the dataloader
        train_loader = DataLoader(
            self.train_dataset,
            sampler=torch.utils.data.RandomSampler(self.train_dataset, replacement=True, num_samples=int(1e10)),
            shuffle=False,
            pin_memory=True,
            batch_size=config.batch_size,
            num_workers=config.num_workers,
        )

        model.train()
        self.iter_num = 0
        self.iter_time = time.time()
        data_iter = iter(train_loader)
        while True:

            # fetch the next batch (x, y) and re-init iterator if needed
            try:
                batch = next(data_iter)
            except StopIteration:
                data_iter = iter(train_loader)
                batch = next(data_iter)
            batch = [t.to(self.device) for t in batch]
            x, y = batch

            # forward the model
            logits, self.loss = model(x, y)

            # backprop and update the parameters
            model.zero_grad(set_to_none=True)
            self.loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), config.grad_norm_clip)
            self.optimizer.step()

            self.trigger_callbacks('on_batch_end')
            self.iter_num += 1
            tnow = time.time()
            self.iter_dt = tnow - self.iter_time
            self.iter_time = tnow

            # termination conditions
            if config.max_iters is not None and self.iter_num >= config.max_iters:
                break

# %%
import pandas as pd
import spacy

train_stories = pd.read_csv('example_train_stories.csv', encoding='utf-8')

nlp = spacy.load('en_core_web_md')
nlp.add_pipe('sentencizer')

def text_to_tokens(text_seqs):
    token_seqs = [[word.lower_ for word in nlp(text_seq)] for text_seq in text_seqs]
    return token_seqs

train_stories['Tokenized_Story'] = text_to_tokens(train_stories['Story'])
    
train_stories[['Story','Tokenized_Story']][:10]
# Out:
#                                                Story  \
# 0  Dan's parents were overweight. Dan was overwei...
# 1  Carrie had just learned how to ride a bike. Sh...
# 2  Morgan enjoyed long walks on the beach. She an...
# 3  Jane was working at a diner. Suddenly a custom...
# 4  I was talking to my crush today. She continued...
# 5  Frank had been drinking beer. He got a call fr...
# 6  Dave was in the Bahamas on vacation. He decide...
# 7  Sunny enjoyed going to the beach. As she stepp...
# 8  Sally was happy when her widowed mom found a n...
# 9  Dan hit his golf ball and watched it go. The b...
#
#                                      Tokenized_Story
# 0  [dan, 's, parents, were, overweight, ., dan, w...
# 1  [carrie, had, just, learned, how, to, ride, a,...
# 2  [morgan, enjoyed, long, walks, on, the, beach,...
# 3  [jane, was, working, at, a, diner, ., suddenly...
# 4  [i, was, talking, to, my, crush, today, ., she...
# 5  [frank, had, been, drinking, beer, ., he, got,...
# 6  [dave, was, in, the, bahamas, on, vacation, .,...
# 7  [sunny, enjoyed, going, to, the, beach, ., as,...
# 8  [sally, was, happy, when, her, widowed, mom, f...
# 9  [dan, hit, his, golf, ball, and, watched, it, ...

# %%
import pickle

def make_vocab(token_seqs, min_freq=1):
    token_counts = {}
    for seq in token_seqs:
        for token in seq:
            if token in token_counts:
                token_counts[token] += 1
            else:
                token_counts[token] = 1

    
    vocab = [token for token, count in token_counts.items() if count >= min_freq]
    
    vocab = {token:idx + 2 for idx,token in enumerate(vocab)}
    vocab[u'<UNK>'] = 1 
    vocab_size = len(vocab)

    print("VOCABULARY SAMPLE ({} total items):".format(len(vocab)))
    print(dict(list(vocab.items())[:20]))
    
    return vocab

vocab = make_vocab(token_seqs=train_stories['Tokenized_Story'], min_freq=1)

with open('vocab.pkl', 'wb') as f:
    pickle.dump(vocab, f)
# Out:
# VOCABULARY SAMPLE (1272 total items):
# {'dan': 2, "'s": 3, 'parents': 4, 'were': 5, 'overweight': 6, '.': 7, 'was': 8, 'as': 9, 'well': 10, 'the': 11, 'doctors': 12, 'told': 13, 'his': 14, 'it': 15, 'unhealthy': 16, 'understood': 17, 'and': 18, 'decided': 19, 'to': 20, 'make': 21}

# %%
def get_vocab_lookup(vocab):
    vocab_lookup = {idx: vocab_item for vocab_item, idx in vocab.items()}
    vocab_lookup[0] = "" 
    print("LOOKUP SAMPLE:")
    print(dict(list(vocab_lookup.items())[:20]))
    return vocab_lookup

vocab_lookup = get_vocab_lookup(vocab)
# Out:
# LOOKUP SAMPLE:
# {2: 'dan', 3: "'s", 4: 'parents', 5: 'were', 6: 'overweight', 7: '.', 8: 'was', 9: 'as', 10: 'well', 11: 'the', 12: 'doctors', 13: 'told', 14: 'his', 15: 'it', 16: 'unhealthy', 17: 'understood', 18: 'and', 19: 'decided', 20: 'to', 21: 'make'}

# %%
def tokens_to_idxs(token_seqs, vocab):
    idx_seqs = [[vocab[token] if token in vocab else vocab['<UNK>'] for token in token_seq]  
                                                                     for token_seq in token_seqs]
    return idx_seqs

train_stories['Story_Idxs'] = tokens_to_idxs(token_seqs=train_stories['Tokenized_Story'], vocab=vocab)
                                   
train_stories[['Tokenized_Story', 'Story_Idxs']][:10]
# Out:
#                                      Tokenized_Story  \
# 0  [dan, 's, parents, were, overweight, ., dan, w...
# 1  [carrie, had, just, learned, how, to, ride, a,...
# 2  [morgan, enjoyed, long, walks, on, the, beach,...
# 3  [jane, was, working, at, a, diner, ., suddenly...
# 4  [i, was, talking, to, my, crush, today, ., she...
# 5  [frank, had, been, drinking, beer, ., he, got,...
# 6  [dave, was, in, the, bahamas, on, vacation, .,...
# 7  [sunny, enjoyed, going, to, the, beach, ., as,...
# 8  [sally, was, happy, when, her, widowed, mom, f...
# 9  [dan, hit, his, golf, ball, and, watched, it, ...
#
#                                           Story_Idxs
# 0  [2, 3, 4, 5, 6, 7, 2, 8, 6, 9, 10, 7, 11, 12, ...
# 1  [29, 30, 31, 32, 33, 20, 34, 22, 35, 7, 36, 37...
# 2  [57, 58, 59, 60, 27, 11, 61, 7, 36, 18, 41, 62...
# 3  [76, 8, 77, 78, 22, 79, 7, 80, 22, 81, 82, 83,...
# 4  [98, 8, 99, 20, 100, 101, 102, 7, 36, 103, 20,...
# 5  [123, 30, 124, 125, 126, 7, 74, 25, 22, 127, 1...
# 6  [146, 8, 147, 11, 148, 27, 149, 7, 74, 19, 20,...
# 7  [169, 58, 170, 20, 11, 61, 7, 9, 36, 171, 121,...
# 8  [182, 8, 183, 159, 41, 184, 185, 160, 22, 186,...
# 9  [2, 203, 14, 204, 205, 18, 206, 15, 63, 7, 11,...

# %%
CONTEXT_SIZE = 8

def sequences_from_data(data, win_len):
    input_data = []
    num_sequences = len(data)
    for i in range(num_sequences):
        sequence = data[i]
        seq_len = len(sequence)
        movil_lim = seq_len - win_len - 2
        for j in range(movil_lim):
            sliding_window = sequence[j:j+win_len+1]
            x = sliding_window[:-1]
            y = sliding_window[1:]
            input_data.append((torch.tensor(x),torch.tensor(y)))
    return input_data

input_data = sequences_from_data(train_stories['Story_Idxs'], CONTEXT_SIZE)

SPLIT = 0.7
num_inputs = len(input_data)
train_lim = math.floor(num_inputs*SPLIT)
train_dataset = input_data[:train_lim]
test_dataset = input_data[train_lim:]

# %%
model_config = GPT.get_default_config()
model_config.model_type = 'gpt-nano'
model_config.vocab_size = len(vocab)
model_config.block_size = CONTEXT_SIZE
model = GPT(model_config)
# Out:
# number of parameters: 0.15M

# %%
CUDA_LAUNCH_BLOCKING = 1
train_config = Trainer.get_default_config()
train_config.learning_rate = 5e-4 
train_config.max_iters = 5000
train_config.num_workers = 0
trainer = Trainer(train_config, model, train_dataset)
# Out:
# running on device cpu

# %%
def batch_end_callback(trainer):
    if trainer.iter_num % 100 == 0:
        print(f"iter_dt {trainer.iter_dt * 1000:.2f}ms; iter {trainer.iter_num}: train loss {trainer.loss.item():.5f}")
trainer.set_callback('on_batch_end', batch_end_callback)

trainer.run()
# Out:
# iter_dt 0.00ms; iter 0: train loss 7.16733
# iter_dt 13.27ms; iter 100: train loss 5.53629
# iter_dt 14.50ms; iter 200: train loss 4.60686
# iter_dt 12.09ms; iter 300: train loss 3.92753
# iter_dt 12.13ms; iter 400: train loss 3.26354
# iter_dt 12.06ms; iter 500: train loss 2.87742
# iter_dt 14.40ms; iter 600: train loss 2.51870
# iter_dt 12.07ms; iter 700: train loss 2.20422
# iter_dt 12.12ms; iter 800: train loss 1.97500
# iter_dt 12.14ms; iter 900: train loss 1.92439
# iter_dt 12.57ms; iter 1000: train loss 1.65203
# iter_dt 14.90ms; iter 1100: train loss 1.56715
# iter_dt 14.71ms; iter 1200: train loss 1.44966
# iter_dt 12.12ms; iter 1300: train loss 1.30608
# iter_dt 12.12ms; iter 1400: train loss 1.19890
# iter_dt 12.18ms; iter 1500: train loss 1.08094
# iter_dt 12.25ms; iter 1600: train loss 1.00235
# iter_dt 12.22ms; iter 1700: train loss 0.90197
# iter_dt 12.21ms; iter 1800: train loss 0.84505
# iter_dt 12.22ms; iter 1900: train loss 0.77765
# iter_dt 12.03ms; iter 2000: train loss 0.74965
# iter_dt 12.15ms; iter 2100: train loss 0.65364
# iter_dt 12.09ms; iter 2200: train loss 0.70064
# iter_dt 12.11ms; iter 2300: train loss 0.59807
# iter_dt 13.74ms; iter 2400: train loss 0.71008
# iter_dt 12.32ms; iter 2500: train loss 0.67644
# iter_dt 12.37ms; iter 2600: train loss 0.68090
# iter_dt 13.15ms; iter 2700: train loss 0.53452
# iter_dt 14.46ms; iter 2800: train loss 0.55366
# iter_dt 12.61ms; iter 2900: train loss 0.55558
# iter_dt 12.06ms; iter 3000: train loss 0.58304
# iter_dt 15.10ms; iter 3100: train loss 0.55747
# iter_dt 12.28ms; iter 3200: train loss 0.55933
# iter_dt 12.30ms; iter 3300: train loss 0.50780
# iter_dt 13.99ms; iter 3400: train loss 0.51394
# iter_dt 13.79ms; iter 3500: train loss 0.53277
# iter_dt 12.29ms; iter 3600: train loss 0.55932
# iter_dt 13.71ms; iter 3700: train loss 0.59020
# iter_dt 17.33ms; iter 3800: train loss 0.55635
# iter_dt 14.55ms; iter 3900: train loss 0.54925
# iter_dt 12.57ms; iter 4000: train loss 0.60714
# iter_dt 12.04ms; iter 4100: train loss 0.47731
# iter_dt 14.13ms; iter 4200: train loss 0.47695
# iter_dt 11.99ms; iter 4300: train loss 0.50567
# iter_dt 13.12ms; iter 4400: train loss 0.44224
# iter_dt 14.00ms; iter 4500: train loss 0.53841
# iter_dt 14.50ms; iter 4600: train loss 0.53399
# iter_dt 16.40ms; iter 4700: train loss 0.40846
# iter_dt 13.14ms; iter 4800: train loss 0.46323
# iter_dt 12.05ms; iter 4900: train loss 0.47474

# %%
def eval_split(trainer, dataset, max_batches):
    n = 8
    split = 4
    correct = 0
    mismatch = 0
    loader = DataLoader(dataset, batch_size=10, num_workers=0, drop_last=False)
    for b, (x, _) in enumerate(loader):
        x = x.to(trainer.device)
        inp_full = x[:, :n]
        inp = x[:, :split]
        cat = model.generate(inp, n, temperature=0.5, do_sample=False) # using greedy argmax, not sampling
        sol = cat[:, :n]
        for i in range(x.size(0)):
            list1 = inp_full[i].tolist()
            text1 = ''
            for idx in list1:
                text1 = text1 + ' ' + vocab_lookup[idx]
            list2 = sol[i].tolist()
            text2 = ''
            for idx in list2:
                text2 = text2 + ' ' + vocab_lookup[idx]
            print("Input: %s , but gpt says: %s" % (text1, text2))
            for j in range(split,split+1):
                    if list1[j] == list2[j]:
                        correct += 1
                    else:
                        mismatch +=1
                        
            
            
        if max_batches is not None and b+1 >= max_batches:
            print("Success rate: %d", correct/(correct+mismatch))
            print("Error rate: %d", mismatch/(correct+mismatch))
            break
    

# run a lot of examples from both train and test through the model and verify the output correctness
with torch.no_grad():
    test_score  = eval_split(trainer, test_dataset,  max_batches=50)
# Out:
# Input:  movies to watch . they had a very , but gpt says:  movies to watch . they had a very
# Input:  to watch . they had a very fun , but gpt says:  to watch . they had a movie was
# Input:  watch . they had a very fun evening , but gpt says:  watch . they had a friend who came
# Input:  . they had a very fun evening and , but gpt says:  . they had a great time but covered
# Input:  they had a very fun evening and sandy , but gpt says:  they had a very grateful to be able
# Input:  had a very fun evening and sandy realized , but gpt says:  had a very fun to hide the candy
# Input:  a very fun evening and sandy realized she , but gpt says:  a very fun evening . the six of
# Input:  very fun evening and sandy realized she had , but gpt says:  very fun evening and the six of them
# Input:  fun evening and sandy realized she had missed , but gpt says:  fun evening and sandy spent a lot of
# Input:  evening and sandy realized she had missed them , but gpt says:  evening and sandy realized his starter was broken
# Input:  and sandy realized she had missed them . , but gpt says:  and sandy realized she forgot something . it
# Input:  sandy realized she had missed them . sandy , but gpt says:  sandy realized she had a lot of money
# Input:  realized she had missed them . sandy was , but gpt says:  realized she had missed . the bus driver
# Input:  she had missed them . sandy was soon , but gpt says:  she had missed them that she was the
# Input:  had missed them . sandy was soon back , but gpt says:  had missed them . the bus driver felt
# Input:  missed them . sandy was soon back to , but gpt says:  missed them . sandy spent the bit had
# Input:  them . sandy was soon back to normal , but gpt says:  them . sandy was a lot of time
# Input:  . sandy was soon back to normal regularly , but gpt says:  . sandy was soon her cart was full
# Input:  sandy was soon back to normal regularly going , but gpt says:  sandy was soon back from his car and
# Input:  was soon back to normal regularly going out , but gpt says:  was soon back to my class . he
# Input:  soon back to normal regularly going out and , but gpt says:  soon back to normal car . she thought
# Input:  bogart lived on a farm . he loved , but gpt says:  bogart lived on a hill and crashed into
# Input:  lived on a farm . he loved bacon , but gpt says:  lived on a farm . i snuck him
# Input:  on a farm . he loved bacon . , but gpt says:  on a farm . i snuck him food
# Input:  a farm . he loved bacon . he , but gpt says:  a farm . he would finally screen in
# Input:  farm . he loved bacon . he decided , but gpt says:  farm . he loved every minute of it
# Input:  . he loved bacon . he decided to , but gpt says:  . he loved bacon of his dad .
# Input:  he loved bacon . he decided to buy , but gpt says:  he loved bacon . the new change of
# Input:  loved bacon . he decided to buy a , but gpt says:  loved bacon . he took her to the
# Input:  bacon . he decided to buy a pig , but gpt says:  bacon . he decided he need to go
# Input:  . he decided to buy a pig . , but gpt says:  . he decided to make a change .
# Input:  he decided to buy a pig . shortly , but gpt says:  he decided to buy something to cook .
# Input:  decided to buy a pig . shortly after , but gpt says:  decided to buy a video of it and
# Input:  to buy a pig . shortly after he , but gpt says:  to buy a pig wandered onto my parents
# Input:  buy a pig . shortly after he grew , but gpt says:  buy a pig . i stepped on his
# Input:  a pig . shortly after he grew fond , but gpt says:  a pig . shortly . they searched for
# Input:  pig . shortly after he grew fond of , but gpt says:  pig . shortly after the exterminator killed all
# Input:  . shortly after he grew fond of the , but gpt says:  . shortly after he won he went on
# Input:  shortly after he grew fond of the pig , but gpt says:  shortly after he grew to he went on
# Input:  after he grew fond of the pig . , but gpt says:  after he grew fond he went to gary
# Input:  he grew fond of the pig . bogart , but gpt says:  he grew fond of the teachers around the
# Input:  grew fond of the pig . bogart stopped , but gpt says:  grew fond of the teachers around the area
# Input:  the preschoolers were going on a field trip , but gpt says:  the preschoolers were going on and looked on
# Input:  preschoolers were going on a field trip . , but gpt says:  preschoolers were going on the beach . as
# Input:  were going on a field trip . their , but gpt says:  were going on a movie and made some
# Input:  going on a field trip . their teachers , but gpt says:  going on a field on to using drugs
# Input:  on a field trip . their teachers took , but gpt says:  on a field trip . he went into
# Input:  a field trip . their teachers took them , but gpt says:  a field trip . he went into the
# Input:  field trip . their teachers took them to , but gpt says:  field trip . their cabin so they called
# Input:  trip . their teachers took them to the , but gpt says:  trip . their teachers around the area helped
# Input:  . their teachers took them to the fire , but gpt says:  . their teachers took the away and now
# Input:  their teachers took them to the fire station , but gpt says:  their teachers took them sat around a big
# Input:  teachers took them to the fire station . , but gpt says:  teachers took them to go home he needed
# Input:  took them to the fire station . they , but gpt says:  took them to the deeper end by herself
# Input:  them to the fire station . they talked , but gpt says:  them to the fire . i got a
# Input:  to the fire station . they talked to , but gpt says:  to the fire station . he snuggled with
# Input:  the fire station . they talked to the , but gpt says:  the fire station . his chip then had
# Input:  fire station . they talked to the firefighters , but gpt says:  fire station . they started dating then adds
# Input:  station . they talked to the firefighters . , but gpt says:  station . they talked to him for an
# Input:  . they talked to the firefighters . they , but gpt says:  . they talked to him for an hour
# Input:  they talked to the firefighters . they saw , but gpt says:  they talked to the for an hour .
# Input:  talked to the firefighters . they saw the , but gpt says:  talked to the firefighters my class and walked
# Input:  to the firefighters . they saw the fire , but gpt says:  to the firefighters . the ball bounced on
# Input:  the firefighters . they saw the fire truck , but gpt says:  the firefighters . they all went out to
# Input:  firefighters . they saw the fire truck . , but gpt says:  firefighters . they saw steward found that the
# Input:  . they saw the fire truck . it , but gpt says:  . they saw the old parish priest pull
# Input:  they saw the fire truck . it was , but gpt says:  they saw the fire all her and the
# Input:  saw the fire truck . it was a , but gpt says:  saw the fire truck and looked at it
# Input:  the fire truck . it was a wonderful , but gpt says:  the fire truck . the shopper gave the
# Input:  gina 's crush sat behind her in class , but gpt says:  gina 's crush sat around a big table
# Input:  's crush sat behind her in class . , but gpt says:  's crush sat behind home and wondered about
# Input:  crush sat behind her in class . he , but gpt says:  crush sat behind her crush today . she
# Input:  the opportunity for an audition came up . , but gpt says:  the opportunity for an hour . i left
# Input:  opportunity for an audition came up . she , but gpt says:  opportunity for an audition in the voice in
# Input:  for an audition came up . she went , but gpt says:  for an audition came and all his work
# Input:  an audition came up . she went for , but gpt says:  an audition came up on his second day
# Input:  audition came up . she went for it , but gpt says:  audition came up . he was terrified when
# Input:  came up . she went for it and , but gpt says:  came up . she took me to the
# Input:  up . she went for it and tried , but gpt says:  up . she went out to have lunch
# Input:  . she went for it and tried out , but gpt says:  . she went for the whole day .
# Input:  she went for it and tried out . , but gpt says:  she went for it . he then a
# Input:  went for it and tried out . amazingly , but gpt says:  went for it and posted it online .
# Input:  for it and tried out . amazingly she , but gpt says:  for it and tried other settings with no
# Input:  it and tried out . amazingly she won , but gpt says:  it and tried out to up on .
# Input:  tim was a salesman . he worked at , but gpt says:  tim was a salesman that looked like it
# Input:  was a salesman . he worked at an , but gpt says:  was a salesman . he decided to go
# Input:  a salesman . he worked at an electronic , but gpt says:  a salesman . he had just seen a
# Input:  salesman . he worked at an electronic store , but gpt says:  salesman . he worked to go snorkeling on
# Input:  . he worked at an electronic store . , but gpt says:  . he worked at it to go .
# Input:  he worked at an electronic store . one , but gpt says:  he worked at an elephant . his mom
# Input:  worked at an electronic store . one day , but gpt says:  worked at an electronic one party he put
# Input:  at an electronic store . one day he , but gpt says:  at an electronic store . inside she walked
# Input:  an electronic store . one day he had , but gpt says:  an electronic store . inside she walked around
# Input:  electronic store . one day he had customers , but gpt says:  electronic store . one day he bought a
# Input:  store . one day he had customers who , but gpt says:  store . one day rex met a nice
# Input:  . one day he had customers who were , but gpt says:  . one day he was gone but i
# Input:  one day he had customers who were unsure , but gpt says:  one day he had a diagram of a
# Input:  day he had customers who were unsure . , but gpt says:  day he had customers to enjoy hot food
# Input:  he had customers who were unsure . he , but gpt says:  he had customers who won the lottery .
# Input:  had customers who were unsure . he convinced , but gpt says:  had customers who were opening eggs and bursting
# Input:  customers who were unsure . he convinced them , but gpt says:  customers who were unsure and looked on in
# Input:  who were unsure . he convinced them to , but gpt says:  who were unsure . amy listened patiently as
# Input:  were unsure . he convinced them to buy , but gpt says:  were unsure . he had just seen a
# Input:  unsure . he convinced them to buy . , but gpt says:  unsure . he convinced his parents understood and
# Input:  . he convinced them to buy . tim , but gpt says:  . he convinced them sat at his house
# Input:  he convinced them to buy . tim even , but gpt says:  he convinced them to her patiently . after
# Input:  convinced them to buy . tim even convinced , but gpt says:  convinced them to buy something to cook .
# Input:  them to buy . tim even convinced them , but gpt says:  them to buy . she heard hundreds voices
# Input:  to buy . tim even convinced them to , but gpt says:  to buy . tim to cook at his
# Input:  buy . tim even convinced them to get , but gpt says:  buy . tim even taught her how to
# Input:  . tim even convinced them to get an , but gpt says:  . tim even convinced his friends were not
# Input:  today was april fools day and everyone played , but gpt says:  today was april fools . him for an
# Input:  was april fools day and everyone played pranks , but gpt says:  was april fools day . kim decided to
# Input:  april fools day and everyone played pranks on , but gpt says:  april fools day and told brenda he needed
# Input:  fools day and everyone played pranks on each , but gpt says:  fools day and everyone was surprised when it
# Input:  day and everyone played pranks on each other , but gpt says:  day and everyone played guitar for 2 hours
# Input:  and everyone played pranks on each other . , but gpt says:  and everyone played pranks that 's bike of
# Input:  everyone played pranks on each other . jeff , but gpt says:  everyone played pranks on the car roof while
# Input:  played pranks on each other . jeff was , but gpt says:  played pranks on each other . they had
# Input:  pranks on each other . jeff was sneaking , but gpt says:  pranks on each other . they had to
# Input:  on each other . jeff was sneaking towards , but gpt says:  on each other . they had to make
# Input:  each other . jeff was sneaking towards dan , but gpt says:  each other . jeff ended up moving to
# Input:  other . jeff was sneaking towards dan who , but gpt says:  other . jeff was far out of tinfoil
# Input:  . jeff was sneaking towards dan who was , but gpt says:  . jeff was sneaking old parish priest pull
# Input:  jeff was sneaking towards dan who was sitting , but gpt says:  jeff was sneaking towards the mall . sunny
# Input:  was sneaking towards dan who was sitting down , but gpt says:  was sneaking towards dan was overweight as well
# Input:  sneaking towards dan who was sitting down . , but gpt says:  sneaking towards dan who won the lottery .
# Input:  towards dan who was sitting down . when , but gpt says:  towards dan who was overweight as well .
# Input:  dan who was sitting down . when jeff , but gpt says:  dan who was sitting in lobby today .
# Input:  who was sitting down . when jeff turned , but gpt says:  who was sitting down payment . jeff ended
# Input:  was sitting down . when jeff turned around , but gpt says:  was sitting down . lobby today he would
# Input:  sitting down . when jeff turned around and , but gpt says:  sitting down . when it was cold one
# Input:  down . when jeff turned around and shouted , but gpt says:  down . when jeff ended up in a
# Input:  . when jeff turned around and shouted . , but gpt says:  . when jeff turned her car into the
# Input:  when jeff turned around and shouted . the , but gpt says:  when jeff turned around the area helped me
# Input:  jeff turned around and shouted . the chair , but gpt says:  jeff turned around and her boyfriend decided to
# Input:  turned around and shouted . the chair ended , but gpt says:  turned around and shouted wait to finish it
# Input:  around and shouted . the chair ended up , but gpt says:  around and shouted . for a pet so
# Input:  and shouted . the chair ended up breaking , but gpt says:  and shouted . the farm . i snuck
# Input:  shouted . the chair ended up breaking when , but gpt says:  shouted . the chair to ride lawn mowers
# Input:  . the chair ended up breaking when jeff , but gpt says:  . the chair ended up hope he found
# Input:  the chair ended up breaking when jeff called , but gpt says:  the chair ended up moving . after a
# Input:  chair ended up breaking when jeff called . , but gpt says:  chair ended up breaking . a new boy
# Input:  ended up breaking when jeff called . dan , but gpt says:  ended up breaking when he entered the movie
# Input:  up breaking when jeff called . dan could , but gpt says:  up breaking when jeff arrived at his house
# Input:  breaking when jeff called . dan could n't , but gpt says:  breaking when jeff called the car and heading
# Input:  when jeff called . dan could n't help , but gpt says:  when jeff called . but the next day
# Input:  betty had a craving for mint ice cream , but gpt says:  betty had a craving of tinfoil . he
# Input:  had a craving for mint ice cream . , but gpt says:  had a craving for a down payment .
# Input:  a craving for mint ice cream . she , but gpt says:  a craving for mint away happily agreed to
# Input:  craving for mint ice cream . she went , but gpt says:  craving for mint ice . they arrived at
# Input:  for mint ice cream . she went to , but gpt says:  for mint ice cream and sugar in his
# Input:  mint ice cream . she went to a , but gpt says:  mint ice cream . at first no one
# Input:  ice cream . she went to a local , but gpt says:  ice cream . she realized his starter was
# Input:  cream . she went to a local ice , but gpt says:  cream . she went to see the deer
# Input:  . she went to a local ice cream , but gpt says:  . she went to the store . inside
# Input:  she went to a local ice cream parlor , but gpt says:  she went to a sharpener and began chanting
# Input:  went to a local ice cream parlor but , but gpt says:  went to a local exterminator who went to
# Input:  to a local ice cream parlor but they , but gpt says:  to a local ice . they started dating
# Input:  a local ice cream parlor but they did , but gpt says:  a local ice cream and sugar in his
# Input:  local ice cream parlor but they did n't , but gpt says:  local ice cream parlor on moving on california
# Input:  ice cream parlor but they did n't have , but gpt says:  ice cream parlor but to her joy peter
# Input:  cream parlor but they did n't have mint , but gpt says:  cream parlor but they started crying . his
# Input:  parlor but they did n't have mint . , but gpt says:  parlor but they did n't say anything .
# Input:  but they did n't have mint . she , but gpt says:  but they did n't have any money .
# Input:  they did n't have mint . she went , but gpt says:  they did n't have any money . one
# Input:  did n't have mint . she went to , but gpt says:  did n't have mint my best to keep
# Input:  n't have mint . she went to a , but gpt says:  n't have mint . soon her cart was
# Input:  have mint . she went to a grocery , but gpt says:  have mint . she realized she should also
# Input:  mint . she went to a grocery store , but gpt says:  mint . she went to the store .
# Input:  . she went to a grocery store but , but gpt says:  . she went to the store . inside
# Input:  she went to a grocery store but they , but gpt says:  she went to a sharpener and began to
# Input:  went to a grocery store but they did , but gpt says:  went to a grocery to using drugs .
# Input:  to a grocery store but they did n't , but gpt says:  to a grocery store todd decided to make
# Input:  a grocery store but they did n't have , but gpt says:  a grocery store but did n't have any
# Input:  grocery store but they did n't have mint , but gpt says:  grocery store but they were surprised to hear
# Input:  store but they did n't have mint either , but gpt says:  store but they did n't have any money
# Input:  but they did n't have mint either . , but gpt says:  but they did n't made it it it
# Input:  they did n't have mint either . betty , but gpt says:  they did n't have any money . one
# Input:  did n't have mint either . betty ended , but gpt says:  did n't have mint . one day he
# Input:  n't have mint either . betty ended up , but gpt says:  n't have mint either and she heard hundreds
# Input:  have mint either . betty ended up buying , but gpt says:  have mint either . he had a diagram
# Input:  mint either . betty ended up buying some , but gpt says:  mint either . betty 's house quickly .
# Input:  either . betty ended up buying some ice , but gpt says:  either . betty ended up moving on california
# Input:  . betty ended up buying some ice some , but gpt says:  . betty ended up moving to a new
# Input:  betty ended up buying some ice some cream , but gpt says:  betty ended up buying some sunglasses and headed
# Input:  ended up buying some ice some cream and , but gpt says:  ended up buying some sunglasses and headed back
# Input:  up buying some ice some cream and some , but gpt says:  up buying some ice was far out of
# Input:  buying some ice some cream and some mint , but gpt says:  buying some ice some sunglasses and headed back
# Input:  some ice some cream and some mint . , but gpt says:  some ice some cream and sugar in his
# Input:  ice some cream and some mint . betty , but gpt says:  ice some cream and sugar in his cup
# Input:  some cream and some mint . betty went , but gpt says:  some cream and some on one day .
# Input:  cream and some mint . betty went home , but gpt says:  cream and some mint on opening night she
# Input:  year cade was the tallest boy in his , but gpt says:  year cade was the class had no clue
# Input:  cade was the tallest boy in his class , but gpt says:  cade was the tallest . she forgot her
# Input:  was the tallest boy in his class . , but gpt says:  was the tallest boy felt . gina realized
# Input:  the tallest boy in his class . cade , but gpt says:  the tallest boy in her class . then
# Input:  tallest boy in his class . cade was , but gpt says:  tallest boy in his place in the line
# Input:  boy in his class . cade was no , but gpt says:  boy in his class . he had no
# Input:  in his class . cade was no longer , but gpt says:  in his class . then a bully began
# Input:  his class . cade was no longer picked , but gpt says:  his class . cade it was completely burnt
# Input:  class . cade was no longer picked on , but gpt says:  class . cade was n't that he did
# Input:  . cade was no longer picked on for , but gpt says:  . cade was no where to sit .
# Input:  amber drove home from work one night . , but gpt says:  amber drove home from his friends the candy
# Input:  drove home from work one night . it , but gpt says:  drove home from work was for nothing .
# Input:  home from work one night . it was , but gpt says:  home from work one for nothing . it
# Input:  from work one night . it was really , but gpt says:  from work one night . kim decided to
# Input:  work one night . it was really bad , but gpt says:  work one night . amy and her friend
# Input:  one night . it was really bad weather , but gpt says:  one night . it on her car she
# Input:  night . it was really bad weather outside , but gpt says:  night . it was n't that he did
# Input:  . it was really bad weather outside . , but gpt says:  . it was really felt like ages .
# Input:  it was really bad weather outside . she , but gpt says:  it was really bad word . the teacher
# Input:  was really bad weather outside . she went , but gpt says:  was really bad weather was cold . but
# Input:  really bad weather outside . she went down , but gpt says:  really bad weather outside . it was cold
# Input:  bad weather outside . she went down a , but gpt says:  bad weather outside . it was cold .
# Input:  weather outside . she went down a dark , but gpt says:  weather outside . she arrived at her new
# Input:  outside . she went down a dark road , but gpt says:  outside . she went to the store .
# Input:  . she went down a dark road that , but gpt says:  . she went down payment . jeff ended
# Input:  she went down a dark road that was , but gpt says:  she went down a man and he did
# Input:  went down a dark road that was covered , but gpt says:  went down a dark . he is a
# Input:  down a dark road that was covered in , but gpt says:  down a dark road he made of tinfoil
# Input:  a dark road that was covered in water , but gpt says:  a dark road that the weather was cold
# Input:  dark road that was covered in water . , but gpt says:  dark road that was made of tinfoil .
# Input:  road that was covered in water . she , but gpt says:  road that was covered in a lot of
# Input:  that was covered in water . she could , but gpt says:  that was covered in a lot of sticky
# Input:  was covered in water . she could not , but gpt says:  was covered in water . they had a
# Input:  covered in water . she could not tell , but gpt says:  covered in water . they had a great
# Input:  in water . she could not tell how , but gpt says:  in water . she played with him everyday
# Input:  water . she could not tell how deep , but gpt says:  water . she could still be in their
# Input:  . she could not tell how deep the , but gpt says:  . she could not drive . frank spent
# Input:  she could not tell how deep the water , but gpt says:  she could not tell josh 's parrot said
# Input:  could not tell how deep the water was , but gpt says:  could not tell how long walk . after
# Input:  not tell how deep the water was and , but gpt says:  not tell how deep gash on her car
# Input:  tell how deep the water was and drove , but gpt says:  tell how deep the deeper end by herself
# Input:  how deep the water was and drove into , but gpt says:  how deep the water and played with him
# Input:  deep the water was and drove into a , but gpt says:  deep the water was far too much .
# Input:  the water was and drove into a flood , but gpt says:  the water was and played with him everyday
# Input:  to buy the car off the seller for , but gpt says:  to buy the car roof while fishing for
# Input:  susie sells the 31 products for extra money , but gpt says:  susie sells the 31 long day of tryouts
# Input:  sells the 31 products for extra money . , but gpt says:  sells the 31 products day of tryouts came
# Input:  the 31 products for extra money . they , but gpt says:  the 31 products for her keys . she
# Input:  31 products for extra money . they are , but gpt says:  31 products for extra in the anticipated .
# Input:  products for extra money . they are totes , but gpt says:  products for extra money to pay for a
# Input:  for extra money . they are totes that , but gpt says:  for extra money . eventually his winnings were
# Input:  extra money . they are totes that are , but gpt says:  extra money . they searched for a shower
# Input:  money . they are totes that are sold , but gpt says:  money . they are wrecked . she is
# Input:  . they are totes that are sold to , but gpt says:  . they are totes to both . after
# Input:  they are totes that are sold to mother , but gpt says:  they are totes that 's what he went
# Input:  are totes that are sold to mother 's , but gpt says:  are totes that are wrecked . she is
# Input:  totes that are sold to mother 's typically , but gpt says:  totes that are sold . it was delicious
# Input:  that are sold to mother 's typically . , but gpt says:  that are sold to walked around looking for
# Input:  are sold to mother 's typically . they , but gpt says:  are sold to mother terrified eyes . jane
# Input:  sold to mother 's typically . they like , but gpt says:  sold to mother 's new husband . although
# Success rate: %d 0.102
# Error rate: %d 0.898

# %%
def eval_split(trainer, dataset, max_batches):
    n = 8
    split = 4
    correct = 0
    mismatch = 0
    loader = DataLoader(dataset, batch_size=10, num_workers=0, drop_last=False)
    for b, (x, _) in enumerate(loader):
        x = x.to(trainer.device)
        inp_full = x[:, :n]
        inp = x[:, :split]
        cat = model.generate(inp, n, temperature=0.1, do_sample=False) # using greedy argmax, not sampling
        sol = cat[:, :n]
        for i in range(x.size(0)):
            list1 = inp_full[i].tolist()
            text1 = ''
            for idx in list1:
                text1 = text1 + ' ' + vocab_lookup[idx]
            list2 = sol[i].tolist()
            text2 = ''
            for idx in list2:
                text2 = text2 + ' ' + vocab_lookup[idx]
            print("Input: %s , but gpt says: %s" % (text1, text2))
            for j in range(split,split+1):
                    if list1[j] == list2[j]:
                        correct += 1
                    else:
                        mismatch +=1
                        
            
            
        if max_batches is not None and b+1 >= max_batches:
            print("Success rate: %d", correct/(correct+mismatch))
            print("Error rate: %d", mismatch/(correct+mismatch))
            break
    

# run a lot of examples from both train and test through the model and verify the output correctness
with torch.no_grad():
    test_score  = eval_split(trainer, test_dataset,  max_batches=50)
# Out:
# Input:  movies to watch . they had a very , but gpt says:  movies to watch . they had a lot
# Input:  to watch . they had a very fun , but gpt says:  to watch . they had a . when
# Input:  watch . they had a very fun evening , but gpt says:  watch . they had a lot to catch
# Input:  . they had a very fun evening and , but gpt says:  . they had a great time but covered
# Input:  they had a very fun evening and sandy , but gpt says:  they had a very cute and popular .
# Input:  had a very fun evening and sandy realized , but gpt says:  had a very fun to hide the candy
# Input:  a very fun evening and sandy realized she , but gpt says:  a very fun evening . the six of
# Input:  very fun evening and sandy realized she had , but gpt says:  very fun evening and the six of them
# Input:  fun evening and sandy realized she had missed , but gpt says:  fun evening and sandy spent six of them
# Input:  field trip . their teachers took them to , but gpt says:  field trip . their path . hal 's
# Input:  trip . their teachers took them to the , but gpt says:  trip . their teachers around the area helped
# Input:  . their teachers took them to the fire , but gpt says:  . their teachers took out of her league
# Input:  their teachers took them to the fire station , but gpt says:  their teachers took them that she had gained
# Input:  teachers took them to the fire station . , but gpt says:  teachers took them to go home and wondered
# Input:  took them to the fire station . they , but gpt says:  took them to the beach . she invited
# Input:  them to the fire station . they talked , but gpt says:  them to the fire . he told me
# Input:  to the fire station . they talked to , but gpt says:  to the fire station . his dog fell
# Input:  the fire station . they talked to the , but gpt says:  the fire station . he decided he need
# Input:  fire station . they talked to the firefighters , but gpt says:  fire station . they started to pour it
# Input:  station . they talked to the firefighters . , but gpt says:  station . they talked to him for an
# Input:  . they talked to the firefighters . they , but gpt says:  . they talked to him for an hour
# Input:  they talked to the firefighters . they saw , but gpt says:  they talked to the for his 16th birthday
# Input:  talked to the firefighters . they saw the , but gpt says:  talked to the firefighters to have lunch .
# Input:  to the firefighters . they saw the fire , but gpt says:  to the firefighters . frank was already a
# Input:  the firefighters . they saw the fire truck , but gpt says:  the firefighters . they her cart was full
# Input:  firefighters . they saw the fire truck . , but gpt says:  firefighters . they saw that all the candy
# Input:  . they saw the fire truck . it , but gpt says:  . they saw the old parish priest pull
# Input:  they saw the fire truck . it was , but gpt says:  they saw the fire all the candy inside
# Input:  saw the fire truck . it was a , but gpt says:  saw the fire truck . his wife and
# Input:  the fire truck . it was a wonderful , but gpt says:  the fire truck . after the exterminator killed
# Input:  gina 's crush sat behind her in class , but gpt says:  gina 's crush sat around a big table
# Input:  's crush sat behind her in class . , but gpt says:  's crush sat behind . but to go
# Input:  crush sat behind her in class . he , but gpt says:  crush sat behind her favorite soccer team was
# Input:  sat behind her in class . he was , but gpt says:  sat behind her in her living room watching
# Input:  behind her in class . he was rude , but gpt says:  behind her in class . then a bully
# Input:  her in class . he was rude . , but gpt says:  her in class . then a bully began
# Input:  in class . he was rude . and , but gpt says:  in class . he decided to go snorkeling
# Input:  class . he was rude . and way , but gpt says:  class . he was sure that 's what
# Input:  . he was rude . and way more , but gpt says:  . he was rude had just listened to
# Input:  he was rude . and way more obnoxious , but gpt says:  he was rude . frank suddenly realized he
# Input:  was rude . and way more obnoxious than , but gpt says:  was rude . and she heard hundreds voices
# Input:  rude . and way more obnoxious than she , but gpt says:  rude . and way to the store todd
# Input:  . and way more obnoxious than she had , but gpt says:  . and way more ! she loved those
# Input:  and way more obnoxious than she had realized , but gpt says:  and way more obnoxious decided to have a
# Input:  way more obnoxious than she had realized . , but gpt says:  way more obnoxious than she anticipated . she
# Input:  more obnoxious than she had realized . she , but gpt says:  more obnoxious than she anticipated . she was
# Input:  obnoxious than she had realized . she began , but gpt says:  obnoxious than she had been being mean to
# Input:  than she had realized . she began to , but gpt says:  than she had realized him always takes it
# Input:  she had realized . she began to dread , but gpt says:  she had realized . they had a exploded
# Input:  had realized . she began to dread seeing , but gpt says:  had realized . she should also apologize to
# Input:  realized . she began to dread seeing him , but gpt says:  realized . she began chanting positive phrases .
# Input:  . she began to dread seeing him . , but gpt says:  . she began to grind it . after
# Input:  she began to dread seeing him . gina , but gpt says:  she began to dread . dan was overweight
# Input:  began to dread seeing him . gina realized , but gpt says:  began to dread seeing the double dip .
# Input:  to dread seeing him . gina realized he , but gpt says:  to dread seeing him double dip . chip
# Input:  dread seeing him . gina realized he was , but gpt says:  dread seeing him . dan decided it was
# Input:  seeing him . gina realized he was n't , but gpt says:  seeing him . gina realized the starter was
# Input:  him . gina realized he was n't her , but gpt says:  him . gina realized she should stop being
# Input:  . gina realized he was n't her type , but gpt says:  . gina realized he had just graduated college
# Input:  olivia was a ballerina . her dream was , but gpt says:  olivia was a ballerina took me to a
# Input:  was a ballerina . her dream was to , but gpt says:  was a ballerina . she wanted to go
# Input:  a ballerina . her dream was to dance , but gpt says:  a ballerina . her about an hour she
# Input:  ballerina . her dream was to dance internationally , but gpt says:  ballerina . her dream was to be a
# Input:  . her dream was to dance internationally . , but gpt says:  . her dream was to be a pilot
# Input:  her dream was to dance internationally . one , but gpt says:  her dream was to be a pilot .
# Input:  dream was to dance internationally . one day , but gpt says:  dream was to dance . but peter was
# Input:  was to dance internationally . one day the , but gpt says:  was to dance internationally but peter was very
# Input:  to dance internationally . one day the opportunity , but gpt says:  to dance internationally . but peter was very
# Input:  dance internationally . one day the opportunity for , but gpt says:  dance internationally . one day rex met a
# Input:  internationally . one day the opportunity for an , but gpt says:  internationally . one day he was gone but
# Input:  . one day the opportunity for an audition , but gpt says:  . one day the place needed meat she
# Input:  one day the opportunity for an audition came , but gpt says:  one day the opportunity . he looked under
# Input:  day the opportunity for an audition came up , but gpt says:  day the opportunity for a pet so i
# Input:  the opportunity for an audition came up . , but gpt says:  the opportunity for an hour . i left
# Input:  opportunity for an audition came up . she , but gpt says:  opportunity for an audition the same . sally
# Input:  for an audition came up . she went , but gpt says:  for an audition came and all his work
# Input:  an audition came up . she went for , but gpt says:  an audition came up in his cup and
# Input:  audition came up . she went for it , but gpt says:  audition came up . he even got his
# Input:  came up . she went for it and , but gpt says:  came up . she put it on her
# Input:  up . she went for it and tried , but gpt says:  up . she went to the store .
# Input:  . she went for it and tried out , but gpt says:  . she went for the whole day .
# Input:  she went for it and tried out . , but gpt says:  she went for it to the spa .
# Input:  went for it and tried out . amazingly , but gpt says:  went for it and posted it online .
# Input:  for it and tried out . amazingly she , but gpt says:  for it and tried other settings with no
# Input:  it and tried out . amazingly she won , but gpt says:  it and tried out to have lunch .
# Input:  tim was a salesman . he worked at , but gpt says:  tim was a salesman . i always wanted
# Input:  was a salesman . he worked at an , but gpt says:  was a salesman . the voice could still
# Input:  a salesman . he worked at an electronic , but gpt says:  a salesman . he took me to the
# Input:  salesman . he worked at an electronic store , but gpt says:  salesman . he worked to the place needed
# Input:  . he worked at an electronic store . , but gpt says:  . he worked at his house . he
# Input:  he worked at an electronic store . one , but gpt says:  he worked at an elephant . his mom
# Input:  worked at an electronic store . one day , but gpt says:  worked at an electronic decided to make a
# Input:  at an electronic store . one day he , but gpt says:  at an electronic store . inside she walked
# Input:  an electronic store . one day he had , but gpt says:  an electronic store . inside she walked around
# Input:  electronic store . one day he had customers , but gpt says:  electronic store . one day rex met a
# Input:  store . one day he had customers who , but gpt says:  store . one day he bought a scratching
# Input:  . one day he had customers who were , but gpt says:  . one day he bought a scratching ticket
# Input:  one day he had customers who were unsure , but gpt says:  one day he had just graduated college .
# Input:  day he had customers who were unsure . , but gpt says:  day he had customers and drove home and
# Input:  he had customers who were unsure . he , but gpt says:  he had customers who won the lottery .
# Input:  had customers who were unsure . he convinced , but gpt says:  had customers who were opening eggs and bursting
# Input:  customers who were unsure . he convinced them , but gpt says:  customers who were unsure the green . his
# Input:  who were unsure . he convinced them to , but gpt says:  who were unsure . amy listened patiently as
# Input:  were unsure . he convinced them to buy , but gpt says:  were unsure . he looked under the hood
# Input:  unsure . he convinced them to buy . , but gpt says:  unsure . he convinced his friends over to
# Input:  . he convinced them to buy . tim , but gpt says:  . he convinced them but she demurred .
# Input:  he convinced them to buy . tim even , but gpt says:  he convinced them to go . she mixed
# Input:  convinced them to buy . tim even convinced , but gpt says:  convinced them to buy something to cook .
# Input:  them to buy . tim even convinced them , but gpt says:  them to buy . she said because she
# Input:  to buy . tim even convinced them to , but gpt says:  to buy . tim to cook at her
# Input:  buy . tim even convinced them to get , but gpt says:  buy . tim even got home i got
# Input:  . tim even convinced them to get an , but gpt says:  . tim even convinced his dog one morning
# Input:  today was april fools day and everyone played , but gpt says:  today was april fools and water and played
# Input:  was april fools day and everyone played pranks , but gpt says:  was april fools day . kim decided to
# Input:  april fools day and everyone played pranks on , but gpt says:  april fools day and told finish the job
# Input:  fools day and everyone played pranks on each , but gpt says:  fools day and everyone was surprised when it
# Input:  day and everyone played pranks on each other , but gpt says:  day and everyone played with him everyday .
# Input:  and everyone played pranks on each other . , but gpt says:  and everyone played pranks listened patiently . she
# Input:  everyone played pranks on each other . jeff , but gpt says:  everyone played pranks on the car hits her
# Input:  played pranks on each other . jeff was , but gpt says:  played pranks on each other . they had
# Input:  pranks on each other . jeff was sneaking , but gpt says:  pranks on each other . they had to
# Input:  on each other . jeff was sneaking towards , but gpt says:  on each other . they had to make
# Input:  each other . jeff was sneaking towards dan , but gpt says:  each other . jeff ended up moving to
# Input:  other . jeff was sneaking towards dan who , but gpt says:  other . jeff was far out of her
# Input:  . jeff was sneaking towards dan who was , but gpt says:  . jeff was sneaking old bit had been
# Input:  jeff was sneaking towards dan who was sitting , but gpt says:  jeff was sneaking towards the mall . sunny
# Input:  was sneaking towards dan who was sitting down , but gpt says:  was sneaking towards dan snuck a ball on
# Input:  sneaking towards dan who was sitting down . , but gpt says:  sneaking towards dan who won the lottery .
# Input:  towards dan who was sitting down . when , but gpt says:  towards dan who was overweight as well .
# Input:  dan who was sitting down . when jeff , but gpt says:  dan who was sitting in lobby today .
# Input:  who was sitting down . when jeff turned , but gpt says:  who was sitting down payment . jeff ended
# Input:  was sitting down . when jeff turned around , but gpt says:  was sitting down . eventually his winnings were
# Input:  sitting down . when jeff turned around and , but gpt says:  sitting down . when it fun to hide
# Input:  down . when jeff turned around and shouted , but gpt says:  down . when jeff ended up moving to
# Input:  . when jeff turned around and shouted . , but gpt says:  . when jeff turned her car into the
# Input:  when jeff turned around and shouted . the , but gpt says:  when jeff turned around the area helped me
# Input:  jeff turned around and shouted . the chair , but gpt says:  jeff turned around and made his putt from
# Input:  turned around and shouted . the chair ended , but gpt says:  turned around and shouted 's for gifts .
# Input:  around and shouted . the chair ended up , but gpt says:  around and shouted . he was a successful
# Input:  and shouted . the chair ended up breaking , but gpt says:  and shouted . the day of tryouts came
# Input:  shouted . the chair ended up breaking when , but gpt says:  shouted . the chair to ride lawn mowers
# Input:  . the chair ended up breaking when jeff , but gpt says:  . the chair ended up ahead . he
# Input:  the chair ended up breaking when jeff called , but gpt says:  the chair ended up moving to a new
# Input:  chair ended up breaking when jeff called . , but gpt says:  chair ended up breaking - powered hearing aid
# Input:  ended up breaking when jeff called . dan , but gpt says:  ended up breaking when it was cold .
# Input:  up breaking when jeff called . dan could , but gpt says:  up breaking when jeff ended up moving to
# Input:  breaking when jeff called . dan could n't , but gpt says:  breaking when jeff called the cat for several
# Input:  when jeff called . dan could n't help , but gpt says:  when jeff called . but the next day
# Input:  betty had a craving for mint ice cream , but gpt says:  betty had a craving up without telling anyone
# Input:  had a craving for mint ice cream . , but gpt says:  had a craving for a hot dog contest
# Input:  a craving for mint ice cream . she , but gpt says:  a craving for mint away by a of
# Input:  craving for mint ice cream . she went , but gpt says:  craving for mint ice . they found feel
# Input:  for mint ice cream . she went to , but gpt says:  for mint ice cream and sugar in his
# Input:  mint ice cream . she went to a , but gpt says:  mint ice cream . at lunch the in
# Input:  ice cream . she went to a local , but gpt says:  ice cream . she realized his starter was
# Input:  cream . she went to a local ice , but gpt says:  cream . she went out to have lunch
# Input:  . she went to a local ice cream , but gpt says:  . she went to the store . inside
# Input:  she went to a local ice cream parlor , but gpt says:  she went to a man and he did
# Input:  went to a local ice cream parlor but , but gpt says:  went to a local exterminator who went to
# Input:  to a local ice cream parlor but they , but gpt says:  to a local ice my crush today .
# Input:  a local ice cream parlor but they did , but gpt says:  a local ice cream and sugar in his
# Input:  local ice cream parlor but they did n't , but gpt says:  local ice cream parlor on christmas morning and
# Input:  ice cream parlor but they did n't have , but gpt says:  ice cream parlor but covered in a lot
# Input:  cream parlor but they did n't have mint , but gpt says:  cream parlor but they started crying . he
# Input:  parlor but they did n't have mint . , but gpt says:  parlor but they did n't have any money
# Input:  but they did n't have mint . she , but gpt says:  but they did n't have any money to
# Input:  they did n't have mint . she went , but gpt says:  they did n't have any money . one
# Input:  did n't have mint . she went to , but gpt says:  did n't have mint . one day he
# Input:  n't have mint . she went to a , but gpt says:  n't have mint . soon her cart was
# Input:  have mint . she went to a grocery , but gpt says:  have mint . she realized his starter was
# Input:  mint . she went to a grocery store , but gpt says:  mint . she went to the store .
# Input:  . she went to a grocery store but , but gpt says:  . she went to the store . inside
# Input:  she went to a grocery store but they , but gpt says:  she went to a shark ! dave swam
# Input:  went to a grocery store but they did , but gpt says:  went to a grocery spa . we both
# Input:  to a grocery store but they did n't , but gpt says:  to a grocery store todd decided to make
# Input:  a grocery store but they did n't have , but gpt says:  a grocery store but inside she walked around
# Input:  grocery store but they did n't have mint , but gpt says:  grocery store but they all went out to
# Input:  store but they did n't have mint either , but gpt says:  store but they did n't say anything .
# Input:  but they did n't have mint either . , but gpt says:  but they did n't say anything . so
# Input:  they did n't have mint either . betty , but gpt says:  they did n't have any money . one
# Input:  did n't have mint either . betty ended , but gpt says:  did n't have mint said a bad word
# Input:  n't have mint either . betty ended up , but gpt says:  n't have mint either to the coffee to
# Input:  have mint either . betty ended up buying , but gpt says:  have mint either . she realized his starter
# Input:  mint either . betty ended up buying some , but gpt says:  mint either . betty ball bounced on the
# Input:  either . betty ended up buying some ice , but gpt says:  either . betty ended up enjoying the job
# Input:  . betty ended up buying some ice some , but gpt says:  . betty ended up moving was california .
# Input:  betty ended up buying some ice some cream , but gpt says:  betty ended up buying ninth . i talked
# Input:  ended up buying some ice some cream and , but gpt says:  ended up buying some sunglasses and headed back
# Input:  up buying some ice some cream and some , but gpt says:  up buying some ice was far out of
# Input:  buying some ice some cream and some mint , but gpt says:  buying some ice some errands . while she
# Input:  some ice some cream and some mint . , but gpt says:  some ice some cream and sugar in his
# Input:  ice some cream and some mint . betty , but gpt says:  ice some cream and sugar in his cup
# Input:  some cream and some mint . betty went , but gpt says:  some cream and some popcorn . the movie
# Input:  cream and some mint . betty went home , but gpt says:  cream and some mint to make a change
# Input:  and some mint . betty went home and , but gpt says:  and some mint . one day he bought
# Input:  some mint . betty went home and made , but gpt says:  some mint . betty 's house quickly .
# Input:  mint . betty went home and made delicious , but gpt says:  mint . betty went on the beach .
# Input:  . betty went home and made delicious ice , but gpt says:  . betty went home and wondered about her
# Input:  cade is short and gets picked on at , but gpt says:  cade is short and he did n't have
# Input:  is short and gets picked on at school , but gpt says:  is short and gets saddest girl out of
# Input:  short and gets picked on at school . , but gpt says:  short and gets picked . i decided he
# Input:  and gets picked on at school . his , but gpt says:  and gets picked on the ground in pain
# Input:  gets picked on at school . his mother , but gpt says:  gets picked on at her mark packed up
# Input:  picked on at school . his mother tells , but gpt says:  picked on at school . since i was
# Input:  on at school . his mother tells him , but gpt says:  on at school . since i was n't
# Input:  at school . his mother tells him he , but gpt says:  at school . his house early that evening
# Input:  school . his mother tells him he will , but gpt says:  school . his mother in long his food
# Input:  . his mother tells him he will soon , but gpt says:  . his mother tells . she looked in
# Input:  his mother tells him he will soon grow , but gpt says:  his mother tells him . mark booked a
# Input:  mother tells him he will soon grow very , but gpt says:  mother tells him he saw a cave up
# Input:  tells him he will soon grow very tall , but gpt says:  tells him he will to pay for a
# Input:  him he will soon grow very tall like , but gpt says:  him he will soon kids . and during
# Input:  he will soon grow very tall like his , but gpt says:  he will soon grow had dan pretended that
# Input:  will soon grow very tall like his dad , but gpt says:  will soon grow very cute and popular .
# Input:  soon grow very tall like his dad . , but gpt says:  soon grow very tall that night he went
# Input:  grow very tall like his dad . within , but gpt says:  grow very tall like it was made of
# Input:  very tall like his dad . within a , but gpt says:  very tall like his dad . his dad
# Input:  tall like his dad . within a few , but gpt says:  tall like his dad . sally went home
# Input:  like his dad . within a few months , but gpt says:  like his dad . sally went home and
# Input:  his dad . within a few months cade , but gpt says:  his dad . within to the store todd
# Input:  dad . within a few months cade had , but gpt says:  dad . within a went out to have
# Input:  . within a few months cade had grow , but gpt says:  . within a few pounds in the last
# Input:  within a few months cade had grow a , but gpt says:  within a few months . the bit from
# Input:  a few months cade had grow a whole , but gpt says:  a few months cade the next day it
# Input:  few months cade had grow a whole inch , but gpt says:  few months cade had gained a few pounds
# Input:  months cade had grow a whole inch . , but gpt says:  months cade had grow . dan snuck him
# Input:  cade had grow a whole inch . and , but gpt says:  cade had grow a call from his girlfriend
# Input:  had grow a whole inch . and within , but gpt says:  had grow a whole day . she was
# Input:  grow a whole inch . and within one , but gpt says:  grow a whole inch coffee . he need
# Input:  a whole inch . and within one year , but gpt says:  a whole inch . about her day .
# Input:  whole inch . and within one year cade , but gpt says:  whole inch . and her boyfriend decided to
# Input:  inch . and within one year cade was , but gpt says:  inch . and within did n't stop to
# Input:  . and within one year cade was the , but gpt says:  . and within one day he bought a
# Input:  and within one year cade was the tallest , but gpt says:  and within one year . he decided he
# Input:  within one year cade was the tallest boy , but gpt says:  within one year cade of it 's that
# Input:  one year cade was the tallest boy in , but gpt says:  one year cade was willing to help me
# Input:  year cade was the tallest boy in his , but gpt says:  year cade was the place needed meat she
# Input:  cade was the tallest boy in his class , but gpt says:  cade was the tallest car hits her and
# Input:  was the tallest boy in his class . , but gpt says:  was the tallest boy felt . gina realized
# Input:  the tallest boy in his class . cade , but gpt says:  the tallest boy in her class . then
# Input:  tallest boy in his class . cade was , but gpt says:  tallest boy in his me up . however
# Input:  boy in his class . cade was no , but gpt says:  boy in his class . he had a
# Input:  in his class . cade was no longer , but gpt says:  in his class . then a bully began
# Input:  his class . cade was no longer picked , but gpt says:  his class . cade it was completely burnt
# Input:  class . cade was no longer picked on , but gpt says:  class . cade was glad that the weather
# Input:  . cade was no longer picked on for , but gpt says:  . cade was no where to sit .
# Input:  amber drove home from work one night . , but gpt says:  amber drove home from his friends he was
# Input:  drove home from work one night . it , but gpt says:  drove home from work and drove 18 hours
# Input:  home from work one night . it was , but gpt says:  home from work one for nothing . it
# Input:  from work one night . it was really , but gpt says:  from work one night for the school play
# Input:  work one night . it was really bad , but gpt says:  work one night . since frank was already
# Input:  one night . it was really bad weather , but gpt says:  one night . it was gone but i
# Input:  night . it was really bad weather outside , but gpt says:  night . it was over kelly won .
# Input:  . it was really bad weather outside . , but gpt says:  . it was really like the ones she
# Input:  it was really bad weather outside . she , but gpt says:  it was really bad word . the teacher
# Input:  was really bad weather outside . she went , but gpt says:  was really bad weather was cold . the
# Input:  really bad weather outside . she went down , but gpt says:  really bad weather outside . it was cold
# Input:  bad weather outside . she went down a , but gpt says:  bad weather outside . it was miserably cold
# Input:  weather outside . she went down a dark , but gpt says:  weather outside . she had been that day
# Input:  outside . she went down a dark road , but gpt says:  outside . she went out to have lunch
# Input:  . she went down a dark road that , but gpt says:  . she went down payment . jeff ended
# Input:  she went down a dark road that was , but gpt says:  she went down a man and looked he
# Input:  went down a dark road that was covered , but gpt says:  went down a dark 's that everyone got
# Input:  down a dark road that was covered in , but gpt says:  down a dark road he bought a scratching
# Input:  a dark road that was covered in water , but gpt says:  a dark road that he had a date
# Input:  dark road that was covered in water . , but gpt says:  dark road that was made of tinfoil .
# Input:  road that was covered in water . she , but gpt says:  road that was covered in a lot of
# Input:  that was covered in water . she could , but gpt says:  that was covered in a lot of use
# Input:  was covered in water . she could not , but gpt says:  was covered in water . they had a
# Input:  covered in water . she could not tell , but gpt says:  covered in water . while she was driving
# Input:  in water . she could not tell how , but gpt says:  in water . she put it on her
# Input:  water . she could not tell how deep , but gpt says:  water . she could but the next day
# Input:  . she could not tell how deep the , but gpt says:  . she could not drive . frank spent
# Input:  she could not tell how deep the water , but gpt says:  she could not tell josh 's parrot said
# Input:  could not tell how deep the water was , but gpt says:  could not tell how to talk to her
# Input:  not tell how deep the water was and , but gpt says:  not tell how deep gash on her car
# Input:  tell how deep the water was and drove , but gpt says:  tell how deep the counter . he began
# Input:  how deep the water was and drove into , but gpt says:  how deep the water . jenna had learned
# Input:  deep the water was and drove into a , but gpt says:  deep the water was far too much .
# Input:  the water was and drove into a flood , but gpt says:  the water was and played with him everyday
# Input:  water was and drove into a flood . , but gpt says:  water was and drove home and the coffee
# Input:  was and drove into a flood . she , but gpt says:  was and drove into town for some errands
# Input:  and drove into a flood . she messed , but gpt says:  and drove into a and heading towards the
# Input:  drove into a flood . she messed up , but gpt says:  drove into a flood coffee to both .
# Input:  into a flood . she messed up her , but gpt says:  into a flood . he even taught her
# Input:  a flood . she messed up her car , but gpt says:  a flood . she demurred . her friends
# Input:  flood . she messed up her car bad , but gpt says:  flood . she messed me up . she
# Input:  . she messed up her car bad and , but gpt says:  . she messed up on any dreams of
# Input:  she messed up her car bad and it , but gpt says:  she messed up her sunglasses . sunny got
# Input:  messed up her car bad and it had , but gpt says:  messed up her car . one day samantha
# Input:  up her car bad and it had to , but gpt says:  up her car bad word . the teacher
# Input:  erica wanted to help her mom this thanksgiving , but gpt says:  erica wanted to help her up . she
# Input:  wanted to help her mom this thanksgiving . , but gpt says:  wanted to help her out of the water
# Input:  to help her mom this thanksgiving . she , but gpt says:  to help her mom 's new husband .
# Input:  help her mom this thanksgiving . she wanted , but gpt says:  help her mom this was as famous as
# Input:  her mom this thanksgiving . she wanted to , but gpt says:  her mom this thanksgiving he would finally screen
# Input:  mom this thanksgiving . she wanted to make , but gpt says:  mom this thanksgiving . when he need to
# Input:  on a bus to her work . she , but gpt says:  on a bus to a man jumped at
# Input:  a bus to her work . she had , but gpt says:  a bus to her patiently . after i
# Input:  bus to her work . she had to , but gpt says:  bus to her work with for nothing .
# Input:  to her work . she had to pee , but gpt says:  to her work . for nothing to eat
# Input:  her work . she had to pee very , but gpt says:  her work . she rehearsed for weeks and
# Input:  work . she had to pee very badly , but gpt says:  work . she had it implanted and then
# Input:  . she had to pee very badly . , but gpt says:  . she had to flip at seeing the
# Input:  she had to pee very badly . she , but gpt says:  she had to pee to go 2nd because
# Input:  had to pee very badly . she could , but gpt says:  had to pee very cute and popular .
# Input:  to pee very badly . she could n't , but gpt says:  to pee very badly . he bring his
# Input:  pee very badly . she could n't hold , but gpt says:  pee very badly . he wanted to break
# Input:  very badly . she could n't hold it , but gpt says:  very badly . she wanted to go 2nd
# Input:  badly . she could n't hold it much , but gpt says:  badly . she could n't wait to finish
# Input:  . she could n't hold it much longer , but gpt says:  . she could n't wait to finish it
# Input:  she could n't hold it much longer . , but gpt says:  she could n't hold to the counter .
# Input:  could n't hold it much longer . she , but gpt says:  could n't hold it was to the best
# Input:  n't hold it much longer . she got , but gpt says:  n't hold it much . he instead called
# Input:  hold it much longer . she got off , but gpt says:  hold it much longer . he instead all
# Input:  it much longer . she got off the , but gpt says:  it much longer . he instead called a
# Input:  much longer . she got off the bus , but gpt says:  much longer . she discovered her siblings did
# Input:  longer . she got off the bus early , but gpt says:  longer . she got nervous on a hill
# Input:  . she got off the bus early to , but gpt says:  . she got off to wash her hands
# Input:  she got off the bus early to pee , but gpt says:  she got off the store todd decided to
# Input:  got off the bus early to pee . , but gpt says:  got off the bus to go out .
# Input:  off the bus early to pee . she , but gpt says:  off the bus early that evening . the
# Input:  the bus early to pee . she caught , but gpt says:  the bus early to save gas so he
# Input:  bus early to pee . she caught the , but gpt says:  bus early to pee of see . after
# Input:  early to pee . she caught the next , but gpt says:  early to pee . after the exterminator killed
# Input:  to pee . she caught the next bus , but gpt says:  to pee . she put it on her
# Input:  james needed a new pick up truck for , but gpt says:  james needed a new kind of super -
# Input:  needed a new pick up truck for work , but gpt says:  needed a new pick me up . he
# Input:  a new pick up truck for work . , but gpt says:  a new pick up . he took me
# Input:  new pick up truck for work . he , but gpt says:  new pick up truck . he took me
# Input:  pick up truck for work . he hauled , but gpt says:  pick up truck for an hour . i
# Input:  up truck for work . he hauled wooden , but gpt says:  up truck for work was for nothing .
# Input:  truck for work . he hauled wooden logs , but gpt says:  truck for work . for that for nothing
# Input:  for work . he hauled wooden logs for , but gpt says:  for work . he gave up his place
# Input:  work . he hauled wooden logs for a , but gpt says:  work . he hauled he bought a scratching
# Input:  . he hauled wooden logs for a living , but gpt says:  . he hauled wooden her boyfriend decided to
# Input:  he hauled wooden logs for a living . , but gpt says:  he hauled wooden logs it on the back
# Input:  hauled wooden logs for a living . he , but gpt says:  hauled wooden logs for weeks to make sure
# Input:  wooden logs for a living . he searched , but gpt says:  wooden logs for a pet so i did
# Input:  logs for a living . he searched all , but gpt says:  logs for a living room watching sports .
# Input:  for a living . he searched all over , but gpt says:  for a living . jane went to see
# Input:  a living . he searched all over on , but gpt says:  a living . he determined he had mice
# Input:  living . he searched all over on craigslist , but gpt says:  living . he searched everywhere she had been
# Input:  . he searched all over on craigslist . , but gpt says:  . he searched all of a young man
# Input:  he searched all over on craigslist . finally , but gpt says:  he searched all over and water . jenna
# Input:  searched all over on craigslist . finally he , but gpt says:  searched all over on a mile something happened
# Input:  all over on craigslist . finally he found , but gpt says:  all over on craigslist cabin . the voice
# Input:  over on craigslist . finally he found a , but gpt says:  over on craigslist . when she put it
# Input:  on craigslist . finally he found a red , but gpt says:  on craigslist . finally they found one and
# Input:  craigslist . finally he found a red truck , but gpt says:  craigslist . finally he decided he need to
# Input:  . finally he found a red truck that , but gpt says:  . finally he found one and decided it
# Input:  finally he found a red truck that he , but gpt says:  finally he found a shark ! dave swam
# Input:  he found a red truck that he liked , but gpt says:  he found a red man trampled by an
# Input:  found a red truck that he liked . , but gpt says:  found a red truck . his dog fell
# Input:  a red truck that he liked . james , but gpt says:  a red truck that the candy inside had
# Input:  red truck that he liked . james was , but gpt says:  red truck that he did n't made it
# Input:  truck that he liked . james was able , but gpt says:  truck that he liked him despite his shortcomings
# Input:  that he liked . james was able to , but gpt says:  that he liked . mark packed up his
# Input:  he liked . james was able to buy , but gpt says:  he liked . james despite his shortcomings .
# Input:  liked . james was able to buy the , but gpt says:  liked . james was full stop to help
# Input:  . james was able to buy the car , but gpt says:  . james was able to properly change her
# Input:  james was able to buy the car off , but gpt says:  james was able to get on the school
# Input:  was able to buy the car off the , but gpt says:  was able to buy something to cook .
# Input:  able to buy the car off the seller , but gpt says:  able to buy the to the science class
# Input:  to buy the car off the seller for , but gpt says:  to buy the car to cook at his
# Input:  susie sells the 31 products for extra money , but gpt says:  susie sells the 31 volcano he looked like
# Input:  sells the 31 products for extra money . , but gpt says:  sells the 31 products 's religion . bob
# Input:  the 31 products for extra money . they , but gpt says:  the 31 products for weeks . on opening
# Input:  31 products for extra money . they are , but gpt says:  31 products for extra . the whole day
# Input:  products for extra money . they are totes , but gpt says:  products for extra money for a down payment
# Input:  for extra money . they are totes that , but gpt says:  for extra money . eventually his winnings were
# Input:  extra money . they are totes that are , but gpt says:  extra money . they searched for a shower
# Input:  money . they are totes that are sold , but gpt says:  money . they are wrecked and she is
# Input:  . they are totes that are sold to , but gpt says:  . they are totes to we had facials
# Input:  they are totes that are sold to mother , but gpt says:  they are totes that 's what he entered
# Input:  are totes that are sold to mother 's , but gpt says:  are totes that are wrecked . she is
# Input:  totes that are sold to mother 's typically , but gpt says:  totes that are sold . he began yelling
# Input:  that are sold to mother 's typically . , but gpt says:  that are sold to pour it in !
# Input:  are sold to mother 's typically . they , but gpt says:  are sold to mother married and eventually had
# Input:  sold to mother 's typically . they like , but gpt says:  sold to mother 's new husband . although
# Success rate: %d 0.11
# Error rate: %d 0.89
